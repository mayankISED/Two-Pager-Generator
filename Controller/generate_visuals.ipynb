# %%
import sys
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd

# Jupyter-safe project root
ROOT_DIR = Path.cwd().parent
sys.path.append(str(ROOT_DIR))

load_dotenv(ROOT_DIR / "credentials.env")

from Config.db import get_db_connection
from Model import visual_data as vd

# %%
import os
print("Host:", os.getenv("host"))
print("User:", os.getenv("user"))
conn = get_db_connection()

result = vd.get_ip_in_force(conn, "United Kingdom", 2010, 2020)
# Out:
# Host: piroesra-dev.cr0w3oonqfj8.ca-central-1.rds.amazonaws.com
# User: mayank.arora
# c:\Users\aroram1\OneDrive - ISED-ISDE\UK Country Profile\Two Pager\Two-Pager-Generator\Model\visual_data.py:40: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
